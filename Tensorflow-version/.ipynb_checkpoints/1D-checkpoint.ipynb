# %%
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import numpy

# %%
path = 'trainingdata.csv'
# Format: channel_acq,test_coupon,num_past_purch,spent_last_purchase,weeks_since_visit,browsing_minutes,shopping_cart,trans_after,revenue_after
# source: https://machinelearningmastery.com/tensorflow-tutorial-deep-learning-with-tf-keras/
trainingdata = read_csv(path, header=None)

path = 'testdata.csv'
testdata = read_csv(path, header=None)

# split into input and output columns
X, y = trainingdata.values[:, :-2], trainingdata.values[:, -2]

# %%
# ensure all data are floating point values
X = X.astype('float32')
# encode strings to integer
y = LabelEncoder().fit_transform(y)
# split into train and test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# determine the number of input features
# Out:
# (2250, 7) (250, 7) (2250,) (250,)

# %%
trainingdata.values[:, -2]
# Out:
# array([0., 0., 0., ..., 1., 0., 0.])

# %%
n_features = X_train.shape[1]


# define model
model = Sequential()
model.add(Dense(10, activation='relu', kernel_initializer='he_normal', input_shape=(n_features,)))
model.add(Dense(8, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))
# compile the model


model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# fit the model
model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=0)
# evaluate the model
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print('Test Accuracy: %.3f' % acc)
# Out:
# Test Accuracy: 0.860

# %%
# make a prediction
row = [ 3.  ,  1.  ,  4.  , 51.99,  0.  , 14.  ,  1. ]
yhat = model.predict([row])
print('Predicted: %.3f' % yhat)
# Out:
# 1/1 [==============================] - 0s 78ms/step
# Predicted: 0.661

# %%
outputdata = []
X, y = testdata.values[:, :-2], testdata.values[:, -2]
for i in range(100):
    yhat = model.predict([list(X[i])])
    outputdata.append([X[i], yhat])
    print('Predicted: %.3f' % yhat)    
    print(y[i])
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Predicted: 0.018
# 0.0
# 1/1 [==============================] - 0s 33ms/step
# Predicted: 0.305
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.067
# 0.0
# 1/1 [==============================] - 0s 33ms/step
# Predicted: 0.127
# 0.0
# 1/1 [==============================] - 0s 34ms/step
# Predicted: 0.005
# 0.0
# 1/1 [==============================] - 0s 33ms/step
# Predicted: 0.040
# 0.0
# 1/1 [==============================] - 0s 33ms/step
# Predicted: 0.026
# 0.0
# 1/1 [==============================] - 0s 35ms/step
# Predicted: 0.302
# 0.0
# 1/1 [==============================] - 0s 35ms/step
# Predicted: 0.195
# 0.0
# 1/1 [==============================] - 0s 34ms/step
# Predicted: 0.077
# 0.0
# 1/1 [==============================] - 0s 34ms/step
# Predicted: 0.014
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.020
# 0.0
# 1/1 [==============================] - 0s 33ms/step
# Predicted: 0.838
# 0.0
# 1/1 [==============================] - 0s 36ms/step
# Predicted: 0.010
# 0.0
# 1/1 [==============================] - 0s 34ms/step
# Predicted: 0.012
# 0.0
# 1/1 [==============================] - 0s 37ms/step
# Predicted: 0.016
# 0.0
# 1/1 [==============================] - 0s 38ms/step
# Predicted: 0.072
# 0.0
# 1/1 [==============================] - 0s 35ms/step
# Predicted: 0.028
# 0.0
# 1/1 [==============================] - 0s 38ms/step
# Predicted: 0.555
# 0.0
# 1/1 [==============================] - 0s 38ms/step
# Predicted: 0.031
# 0.0
# 1/1 [==============================] - 0s 38ms/step
# Predicted: 0.078
# 0.0
# 1/1 [==============================] - 0s 36ms/step
# Predicted: 0.007
# 0.0
# 1/1 [==============================] - 0s 33ms/step
# Predicted: 0.129
# 0.0
# 1/1 [==============================] - 0s 37ms/step
# Predicted: 0.007
# 0.0
# 1/1 [==============================] - 0s 38ms/step
# Predicted: 0.077
# 0.0
# 1/1 [==============================] - 0s 39ms/step
# Predicted: 0.065
# 0.0
# 1/1 [==============================] - 0s 36ms/step
# Predicted: 0.035
# 0.0
# 1/1 [==============================] - 0s 37ms/step
# Predicted: 0.009
# 0.0
# 1/1 [==============================] - 0s 37ms/step
# Predicted: 0.008
# 0.0
# 1/1 [==============================] - 0s 37ms/step
# Predicted: 0.188
# 0.0
# 1/1 [==============================] - 0s 37ms/step
# Predicted: 0.134
# 1.0
# 1/1 [==============================] - 0s 40ms/step
# Predicted: 0.050
# 0.0
# 1/1 [==============================] - 0s 42ms/step
# Predicted: 0.014
# 0.0
# 1/1 [==============================] - 0s 43ms/step
# Predicted: 0.042
# 0.0
# 1/1 [==============================] - 0s 43ms/step
# Predicted: 0.152
# 0.0
# 1/1 [==============================] - 0s 37ms/step
# Predicted: 0.268
# 0.0
# 1/1 [==============================] - 0s 37ms/step
# Predicted: 0.204
# 0.0
# 1/1 [==============================] - 0s 38ms/step
# Predicted: 0.033
# 0.0
# 1/1 [==============================] - 0s 36ms/step
# Predicted: 0.011
# 0.0
# 1/1 [==============================] - 0s 37ms/step
# Predicted: 0.522
# 0.0
# 1/1 [==============================] - 0s 34ms/step
# Predicted: 0.438
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# Predicted: 0.161
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.021
# 0.0
# 1/1 [==============================] - 0s 35ms/step
# Predicted: 0.024
# 0.0
# 1/1 [==============================] - 0s 36ms/step
# Predicted: 0.052
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.008
# 0.0
# 1/1 [==============================] - 0s 33ms/step
# Predicted: 0.035
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.017
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.245
# 0.0
# 1/1 [==============================] - 0s 34ms/step
# Predicted: 0.008
# 0.0
# 1/1 [==============================] - 0s 40ms/step
# Predicted: 0.043
# 0.0
# 1/1 [==============================] - 0s 37ms/step
# Predicted: 0.487
# 0.0
# 1/1 [==============================] - 0s 34ms/step
# Predicted: 0.017
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.024
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.020
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.056
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.226
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.066
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.045
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.079
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.680
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.281
# 0.0
# 1/1 [==============================] - 0s 36ms/step
# Predicted: 0.982
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# Predicted: 0.485
# 0.0
# 1/1 [==============================] - 0s 34ms/step
# Predicted: 0.042
# 0.0
# 1/1 [==============================] - 0s 33ms/step
# Predicted: 0.045
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.034
# 0.0
# 1/1 [==============================] - 0s 30ms/step
# Predicted: 0.213
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.055
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.705
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# Predicted: 0.029
# 0.0
# 1/1 [==============================] - 0s 34ms/step
# Predicted: 0.573
# 2.0
# 1/1 [==============================] - 0s 33ms/step
# Predicted: 0.133
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.009
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.048
# 0.0
# 1/1 [==============================] - 0s 30ms/step
# Predicted: 0.246
# 0.0
# 1/1 [==============================] - 0s 30ms/step
# Predicted: 0.032
# 0.0
# 1/1 [==============================] - 0s 39ms/step
# Predicted: 0.297
# 0.0
# 1/1 [==============================] - 0s 36ms/step
# Predicted: 0.227
# 0.0
# 1/1 [==============================] - 0s 30ms/step
# Predicted: 0.077
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.259
# 0.0
# 1/1 [==============================] - 0s 29ms/step
# Predicted: 0.528
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.088
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.324
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.221
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.022
# 0.0
# 1/1 [==============================] - 0s 55ms/step
# Predicted: 0.248
# 0.0
# 1/1 [==============================] - 0s 29ms/step
# Predicted: 0.013
# 0.0
# 1/1 [==============================] - 0s 30ms/step
# Predicted: 0.051
# 0.0
# 1/1 [==============================] - 0s 29ms/step
# Predicted: 0.037
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.459
# 0.0
# 1/1 [==============================] - 0s 31ms/step
# Predicted: 0.006
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.052
# 0.0
# 1/1 [==============================] - 0s 34ms/step
# Predicted: 0.024
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.049
# 0.0
# 1/1 [==============================] - 0s 32ms/step
# Predicted: 0.202
# 0.0
# 1/1 [==============================] - 0s 30ms/step
# Predicted: 0.028
# 0.0
# 1/1 [==============================] - 0s 33ms/step
# Predicted: 0.007
# 0.0
# 1/1 [==============================] - 0s 30ms/step
# Predicted: 0.134
# 0.0
# 1/1 [==============================] - 0s 29ms/step
# Predicted: 0.045
# 0.0

# %%
outputdata
# Out:
# [array([[0.01835616]], dtype=float32),
#  array([[0.30458966]], dtype=float32),
#  array([[0.06738599]], dtype=float32),
#  array([[0.12690051]], dtype=float32),
#  array([[0.00488813]], dtype=float32),
#  array([[0.04013934]], dtype=float32),
#  array([[0.02643674]], dtype=float32),
#  array([[0.30168033]], dtype=float32),
#  array([[0.19533044]], dtype=float32),
#  array([[0.0772153]], dtype=float32),
#  array([[0.01416343]], dtype=float32),
#  array([[0.0199951]], dtype=float32),
#  array([[0.83758134]], dtype=float32),
#  array([[0.00998472]], dtype=float32),
#  array([[0.01239034]], dtype=float32),
#  array([[0.01563107]], dtype=float32),
#  array([[0.07193494]], dtype=float32),
#  array([[0.02838066]], dtype=float32),
#  array([[0.5547995]], dtype=float32),
#  array([[0.03135718]], dtype=float32),
#  array([[0.07848721]], dtype=float32),
#  array([[0.0066146]], dtype=float32),
#  array([[0.12856023]], dtype=float32),
#  array([[0.00653438]], dtype=float32),
#  array([[0.07674972]], dtype=float32),
#  array([[0.06468148]], dtype=float32),
#  array([[0.03544538]], dtype=float32),
#  array([[0.00911128]], dtype=float32),
#  array([[0.0078924]], dtype=float32),
#  array([[0.18822636]], dtype=float32),
#  array([[0.1341845]], dtype=float32),
#  array([[0.04954871]], dtype=float32),
#  array([[0.01390607]], dtype=float32),
#  array([[0.04211184]], dtype=float32),
#  array([[0.15154746]], dtype=float32),
#  array([[0.267657]], dtype=float32),
#  array([[0.20409524]], dtype=float32),
#  array([[0.03332356]], dtype=float32),
#  array([[0.01080098]], dtype=float32),
#  array([[0.522484]], dtype=float32),
#  array([[0.43805647]], dtype=float32),
#  array([[0.16110523]], dtype=float32),
#  array([[0.02106348]], dtype=float32),
#  array([[0.02396377]], dtype=float32),
#  array([[0.05185071]], dtype=float32),
#  array([[0.00814621]], dtype=float32),
#  array([[0.03508889]], dtype=float32),
#  array([[0.01651041]], dtype=float32),
#  array([[0.24480861]], dtype=float32),
#  array([[0.00827017]], dtype=float32),
#  array([[0.04263853]], dtype=float32),
#  array([[0.48671135]], dtype=float32),
#  array([[0.01655412]], dtype=float32),
#  array([[0.02390595]], dtype=float32),
#  array([[0.01964283]], dtype=float32),
#  array([[0.05606109]], dtype=float32),
#  array([[0.22557782]], dtype=float32),
#  array([[0.06640343]], dtype=float32),
#  array([[0.04519634]], dtype=float32),
#  array([[0.07948893]], dtype=float32),
#  array([[0.67957884]], dtype=float32),
#  array([[0.2812764]], dtype=float32),
#  array([[0.982261]], dtype=float32),
#  array([[0.48491567]], dtype=float32),
#  array([[0.04220711]], dtype=float32),
#  array([[0.04455482]], dtype=float32),
#  array([[0.03421419]], dtype=float32),
#  array([[0.21265882]], dtype=float32),
#  array([[0.05482298]], dtype=float32),
#  array([[0.70480776]], dtype=float32),
#  array([[0.02948512]], dtype=float32),
#  array([[0.5730123]], dtype=float32),
#  array([[0.13292436]], dtype=float32),
#  array([[0.00892015]], dtype=float32),
#  array([[0.04819958]], dtype=float32),
#  array([[0.2464996]], dtype=float32),
#  array([[0.03233483]], dtype=float32),
#  array([[0.29735073]], dtype=float32),
#  array([[0.22712478]], dtype=float32),
#  array([[0.07686364]], dtype=float32),
#  array([[0.25919637]], dtype=float32),
#  array([[0.52813166]], dtype=float32),
#  array([[0.08780656]], dtype=float32),
#  array([[0.3243013]], dtype=float32),
#  array([[0.2206994]], dtype=float32),
#  array([[0.02188409]], dtype=float32),
#  array([[0.24803407]], dtype=float32),
#  array([[0.01342414]], dtype=float32),
#  array([[0.05073432]], dtype=float32),
#  array([[0.03719286]], dtype=float32),
#  array([[0.4592548]], dtype=float32),
#  array([[0.00609894]], dtype=float32),
#  array([[0.05241032]], dtype=float32),
#  array([[0.02392358]], dtype=float32),
#  array([[0.04945065]], dtype=float32),
#  array([[0.20212376]], dtype=float32),
#  array([[0.02758592]], dtype=float32),
#  array([[0.00669156]], dtype=float32),
#  array([[0.1344267]], dtype=float32),
#  array([[0.04497899]], dtype=float32)]

# %%
y_test[4]
